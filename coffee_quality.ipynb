# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = 'data/coffee/'
files = os.listdir(file_path)
files

# %%
df = pd.read_csv(file_path+files[0])
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.columns
